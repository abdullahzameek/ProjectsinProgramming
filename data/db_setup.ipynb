# %%
# !pip install pymongo dnspython
# Out:
# ...
#      |████████████████████████████████| 241 kB 6.1 MB/s eta 0:00:01
# ...

# %%
import pymongo
import dns
import pandas as pd 
import numpy as np

# %%
#put in the string i sent over here
ATLAS_URI = "mongodb+srv://nyumongo:nyumongo@cluster0.tolqi.mongodb.net/ProjectsinProgramming?retryWrites=true&w=majority"

# %%
client = pymongo.MongoClient(ATLAS_URI)

# %%
db = client['ProjectsinProgramming']

# %%
yellowTaxiTable = db['YellowTaxi']
uberLyftTable = db['UberLyftStuff']

# %%
yellowTaxi_df = pd.DataFrame(list(yellowTaxiTable.find()))

# %%
yellowTaxi_df
# Out:
#                              _id                            key  fare_amount  \
# 0       608328c055a7bf9dfb58cd9a    2009-06-15 17:26:21.0000001          4.5
# 1       608328c055a7bf9dfb58cd9b    2010-01-05 16:52:16.0000002         16.9
# 2       608328c055a7bf9dfb58cd9c   2011-08-18 00:35:00.00000049          5.7
# 3       608328c055a7bf9dfb58cd9d    2012-04-21 04:30:42.0000001          7.7
# 4       608328c055a7bf9dfb58cd9e  2010-03-09 07:51:00.000000135          5.3
# ...                          ...                            ...          ...
# 693065  60832b2355a7bf9dfb6360e3    2010-02-12 12:03:21.0000003          9.7
# 693066  60832b2355a7bf9dfb6360e4    2011-07-22 11:46:20.0000002         23.7
# 693067  60832b2355a7bf9dfb6360e5    2011-09-07 10:29:16.0000002          4.5
# 693068  60832b2355a7bf9dfb6360e6    2009-10-12 12:58:42.0000003          6.5
# 693069  60832b2355a7bf9dfb6360e7    2009-10-18 18:45:42.0000001          6.9
#
# ...

# %%
uber_df = pd.DataFrame(list(uberLyftTable.find({"cab_type":"Uber"})))

# %%
uber_df
# Out:
#                              _id  distance cab_type          time_stamp  \
# 0       607f3e3d2e3d002771568a72      1.11     Uber 2021-04-20 20:34:28
# 1       607f3e3d2e3d002771568a73      1.11     Uber 2021-04-20 20:34:28
# 2       607f3e3d2e3d002771568a74      1.11     Uber 2021-04-20 20:34:28
# 3       607f3e3d2e3d002771568a75      1.11     Uber 2021-04-20 20:34:28
# 4       607f3e3d2e3d002771568a76      1.11     Uber 2021-04-20 20:34:28
# ...                          ...       ...      ...                 ...
# 379356  607f41b42e3d00277160f255      0.68     Uber 2021-04-20 20:34:28
# 379357  607f41b42e3d00277160f256      0.68     Uber 2021-04-20 20:34:28
# 379358  607f41b42e3d00277160f257      0.68     Uber 2021-04-20 20:34:28
# 379359  607f41b42e3d00277160f258      0.68     Uber 2021-04-20 20:34:28
# 379360  607f41b42e3d00277160f275      0.30     Uber 2021-04-20 20:34:28
#
#           destination            source  price  surge_multiplier  \
# ...

# %%
lyft_df = pd.DataFrame(list(uberLyftTable.find({"cab_type":"Lyft"})))

# %%
lyft_df
# Out:
#                              _id  distance cab_type          time_stamp  \
# 0       607f3e3d2e3d002771568a66      0.44     Lyft 2021-04-20 20:34:28
# 1       607f3e3d2e3d002771568a67      0.44     Lyft 2021-04-20 20:34:28
# 2       607f3e3d2e3d002771568a68      0.44     Lyft 2021-04-20 20:34:28
# 3       607f3e3d2e3d002771568a69      0.44     Lyft 2021-04-20 20:34:28
# 4       607f3e3d2e3d002771568a6a      0.44     Lyft 2021-04-20 20:34:28
# ...                          ...       ...      ...                 ...
# 302634  607f41b42e3d00277160f270      2.83     Lyft 2021-04-20 20:34:28
# 302635  607f41b42e3d00277160f271      2.83     Lyft 2021-04-20 20:34:28
# 302636  607f41b42e3d00277160f272      2.83     Lyft 2021-04-20 20:34:28
# 302637  607f41b42e3d00277160f273      2.83     Lyft 2021-04-20 20:34:28
# 302638  607f41b42e3d00277160f274      2.83     Lyft 2021-04-20 20:34:28
#
#           destination            source  price  surge_multiplier  \
# ...
